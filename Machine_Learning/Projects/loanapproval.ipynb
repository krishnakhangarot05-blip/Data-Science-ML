# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\loan_data.csv")

# %% [markdown]
# #Understanding the data

# %% [markdown]
# #CHECK FIRST ROWS

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %% [markdown]
# #CHECK COLUMN NAMES

# %%
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='str')

# %% [markdown]
# #CHECK DATA TYPES

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  str
#  2   person_education                45000 non-null  str
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  str
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  str
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %% [markdown]
# # GET SUMMARY OF THE DATAFRAME

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %% [markdown]
# 🔹 Common Cleaning Steps for Loan Data
#
# Loan datasets usually contain:
#
# Missing values
#
# Duplicate rows
#
# Wrong data types
#
# Outliers
#
# Inconsistent text (Male/male/MALE)
#
# Extra spaces

# %% [markdown]
# 2.Handling missing values

# %% [markdown]
# #CHECK MISSING VALUES

# %% [markdown]
# df.isnull().sum()
#
# 👉 It counts total missing values in each column.
#
# Why?
#
# Because:
#
# True = 1
#
# False = 0
#
# .sum() adds them
#
#
# df.isnull()
#
# 👉 It checks every cell in the dataset and tells:
#
# True → if value is missing (NaN)
#
# False → if value is present

# %%
df.isnull()
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0           False          False             False          False
# 1           False          False             False          False
# 2           False          False             False          False
# 3           False          False             False          False
# 4           False          False             False          False
# ...           ...            ...               ...            ...
# 44995       False          False             False          False
# 44996       False          False             False          False
# 44997       False          False             False          False
# 44998       False          False             False          False
# 44999       False          False             False          False
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0               False                  False      False        False
# ...

# %%
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %% [markdown]
# Drop rows with missing values

# %%
df.dropna(inplace=True)

# %% [markdown]
# Fill missing values
#
# For numeric columns:

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %% [markdown]
# Remove Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
#  df.drop_duplicates(inplace=True) :-Removes duplicate rows from the dataset permanently

# %%
pd=df.drop_duplicates(inplace=True)

# %% [markdown]
# df.fillna(0) :-replaces all missing values (NaN) in the DataFrame with 0.

# %% [markdown]
# inplace=True
#
# This means:
#
# Make changes directly in the original DataFrame.

# %%
df.fillna(0)
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %% [markdown]
# #IT PRINTS THE FIRST TEN ROWS OF THE DATAFRAME

# %%
df.head(10)
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
# 5        21.0        female      High School        12951.0               0
# 6        26.0        female         Bachelor        93471.0               1
# 7        24.0        female      High School        95550.0               5
# 8        24.0        female        Associate       100684.0               3
# 9        21.0        female      High School        12739.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# ...

# %% [markdown]
# #IT PRINTS THE LAST TEN ROWS OF THE DATAFRAME

# %%
df.tail(10)
# Out:
#        person_age person_gender person_education  person_income  \
# 44990        31.0          male           Master       136832.0
# 44991        24.0          male      High School        37786.0
# 44992        23.0        female         Bachelor        40925.0
# 44993        27.0        female      High School        35512.0
# 44994        24.0        female        Associate        31924.0
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 44990               9                  RENT    12319.0           PERSONAL
# 44991               0              MORTGAGE    13500.0          EDUCATION
# ...

# %%
df.person_age
# Out:
# 0        22.0
# 1        21.0
# 2        25.0
# 3        23.0
# 4        24.0
#          ...
# 44995    27.0
# 44996    37.0
# 44997    33.0
# 44998    29.0
# 44999    24.0
# Name: person_age, Length: 45000, dtype: float64

# %%
df.person_education
# Out:
# 0             Master
# 1        High School
# 2        High School
# 3           Bachelor
# 4             Master
#             ...
# 44995      Associate
# 44996      Associate
# 44997      Associate
# 44998       Bachelor
# 44999    High School
# Name: person_education, Length: 45000, dtype: str

# %%
df.person_gender
# Out:
# 0        female
# 1        female
# 2        female
# 3        female
# 4          male
#           ...
# 44995      male
# 44996    female
# 44997      male
# 44998      male
# 44999      male
# Name: person_gender, Length: 45000, dtype: str

# %% [markdown]
#  df.duplicated().sum():-This command tells you How many duplicate rows are present in your dataset

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# unique():
# Returns all different (distinct) values present in a column.

# %%
df['person_age'].unique()
# Out:
# array([ 22.,  21.,  25.,  23.,  24.,  26., 144., 123.,  20.,  32.,  34.,
#         29.,  33.,  28.,  35.,  31.,  27.,  30.,  36.,  40.,  50.,  45.,
#         37.,  39.,  44.,  43.,  41.,  46.,  38.,  47.,  42.,  48.,  49.,
#         58.,  65.,  51.,  53.,  66.,  61.,  54.,  57.,  59.,  62.,  60.,
#         55.,  52.,  64.,  70.,  78.,  69.,  56.,  73.,  63.,  94.,  80.,
#         84.,  76.,  67., 116., 109.])

# %% [markdown]
# nunique():
# Returns number of unique values in a column.

# %%
df['person_education'].nunique()
# Out:
# 5

# %% [markdown]
# value_counts():
# Counts how many times each value appears in a column.

# %%
df['person_education'].value_counts()
# Out:
# person_education
# Bachelor       13399
# Associate      12028
# High School    11972
# Master          6980
# Doctorate        621
# Name: count, dtype: int64

# %% [markdown]
# #we can drop any two column from a dataframe("axis=1"is used to drop a column) (axis=0 is used to drop a row)

# %%
df.drop(["person_age","person_education"],axis=1,inplace=True)

# %%
df
# Out:
#       person_gender  person_income  person_emp_exp person_home_ownership  \
# 0            female        71948.0               0                  RENT
# 1            female        12282.0               0                   OWN
# 2            female        12438.0               3              MORTGAGE
# 3            female        79753.0               0                  RENT
# 4              male        66135.0               1                  RENT
# ...             ...            ...             ...                   ...
# 44995          male        47971.0               6                  RENT
# 44996        female        65800.0              17                  RENT
# 44997          male        56942.0               7                  RENT
# 44998          male        33164.0               4                  RENT
# 44999          male        51609.0               1                  RENT
#
#        loan_amnt        loan_intent  loan_int_rate  loan_percent_income  \
# ...

# %%
char = df.select_dtypes(include="object")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18680\2025809274.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   char = df.select_dtypes(include="object")

# %%
char
# Out:
#       person_gender person_home_ownership        loan_intent  \
# 0            female                  RENT           PERSONAL
# 1            female                   OWN          EDUCATION
# 2            female              MORTGAGE            MEDICAL
# 3            female                  RENT            MEDICAL
# 4              male                  RENT            MEDICAL
# ...             ...                   ...                ...
# 44995          male                  RENT            MEDICAL
# 44996        female                  RENT    HOMEIMPROVEMENT
# 44997          male                  RENT  DEBTCONSOLIDATION
# 44998          male                  RENT          EDUCATION
# 44999          male                  RENT  DEBTCONSOLIDATION
#
#       previous_loan_defaults_on_file
# 0                                 No
# 1                                Yes
# 2                                 No
# 3                                 No
# 4                                 No
# ...

# %% [markdown]
# df → Your pandas DataFrame.
#
# select_dtypes() → A pandas method used to select columns based on their data type.
#
# include="object" → Selects columns with data type object.
#
# char → A new DataFrame containing only those selected columns.

# %% [markdown]
# df → Your pandas DataFrame
#
# select_dtypes() → Selects columns based on data type
#
# exclude="object" → Excludes columns with data type object
#
# iint → A new DataFrame storing the result

# %%
iint=df.select_dtypes(exclude="object")

# %%
iint
# Out:
#        person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0            71948.0               0    35000.0          16.02
# 1            12282.0               0     1000.0          11.14
# 2            12438.0               3     5500.0          12.87
# 3            79753.0               0    35000.0          15.23
# 4            66135.0               1    35000.0          14.27
# ...              ...             ...        ...            ...
# 44995        47971.0               6    15000.0          15.66
# 44996        65800.0              17     9000.0          14.07
# 44997        56942.0               7     2771.0          10.02
# 44998        33164.0               4    12000.0          13.23
# 44999        51609.0               1     6665.0          17.05
#
#        loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                     0.49                         3.0           561
# ...

# %% [markdown]
# df → Your pandas DataFrame
#
# ["loan_amnt"] → Selects the column named "loan_amnt"
#
# .unique() → A pandas method that returns all the unique (distinct) values in that column

# %%
df["loan_amnt"].unique()
# Out:
# array([35000.,  1000.,  5500., ..., 12229.,  2771.,  6665.], shape=(4483,))

# %% [markdown]
# df → Your pandas DataFrame
#
# rename() → A pandas function used to rename rows or columns
#
# columns={"age":"module"} →
#
# "age" → Old column name
#
# "module" → New column name
#
# So this line renames the column age to module.

# %%
df.rename(columns={"age":"module"})
# Out:
#       person_gender  person_income  person_emp_exp person_home_ownership  \
# 0            female        71948.0               0                  RENT
# 1            female        12282.0               0                   OWN
# 2            female        12438.0               3              MORTGAGE
# 3            female        79753.0               0                  RENT
# 4              male        66135.0               1                  RENT
# ...             ...            ...             ...                   ...
# 44995          male        47971.0               6                  RENT
# 44996        female        65800.0              17                  RENT
# 44997          male        56942.0               7                  RENT
# 44998          male        33164.0               4                  RENT
# 44999          male        51609.0               1                  RENT
#
#        loan_amnt        loan_intent  loan_int_rate  loan_percent_income  \
# ...

# %%
loan_dict = {"person_gender": 1, "person_income": 2,"person_emp_exp":3,"person_home_ownership":4,"loan_amnt":5}

# %%
loan_dict
# Out:
# {'person_gender': 1,
#  'person_income': 2,
#  'person_emp_exp': 3,
#  'person_home_ownership': 4,
#  'loan_amnt': 5}

# %% [markdown]
# map() is a method for pandas Series (columns). It applies a function or a dictionary to each value in the column.

# %%
df['person_gender']=df['person_gender'].map(loan_dict)

# %%
df
# Out:
#        person_gender  person_income  person_emp_exp person_home_ownership  \
# 0                NaN        71948.0               0                  RENT
# 1                NaN        12282.0               0                   OWN
# 2                NaN        12438.0               3              MORTGAGE
# 3                NaN        79753.0               0                  RENT
# 4                NaN        66135.0               1                  RENT
# ...              ...            ...             ...                   ...
# 44995            NaN        47971.0               6                  RENT
# 44996            NaN        65800.0              17                  RENT
# 44997            NaN        56942.0               7                  RENT
# 44998            NaN        33164.0               4                  RENT
# 44999            NaN        51609.0               1                  RENT
#
#        loan_amnt        loan_intent  loan_int_rate  loan_percent_income  \
# ...

# %%
df.to_csv('loanapproval.csv')

# %%
df
# Out:
#        person_gender  person_income  person_emp_exp person_home_ownership  \
# 0                NaN        71948.0               0                  RENT
# 1                NaN        12282.0               0                   OWN
# 2                NaN        12438.0               3              MORTGAGE
# 3                NaN        79753.0               0                  RENT
# 4                NaN        66135.0               1                  RENT
# ...              ...            ...             ...                   ...
# 44995            NaN        47971.0               6                  RENT
# 44996            NaN        65800.0              17                  RENT
# 44997            NaN        56942.0               7                  RENT
# 44998            NaN        33164.0               4                  RENT
# 44999            NaN        51609.0               1                  RENT
#
#        loan_amnt        loan_intent  loan_int_rate  loan_percent_income  \
# ...
